# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num_samples = 1000
sample_size = 30
distribution_range = (0,1)

# Generate samples from uniform distribution
samples = np.random.uniform(distribution_range[0], distribution_range[1],(num_samples,sample_size))

# Calculate the sample mean
sample_mean = np.mean(samples,axis=1)

# plot the histogram of the sample means
plt.figure(figsize=(8,2))
plt.hist(sample_mean, density=True, bins=30, edgecolor='black')
plt.title('Histogram of Sample Mean')
plt.xlabel('Sample_Mean')
plt.ylabel('Density')
plt.show()
print()
print('='*35)
print('samples : ',samples)
print('='*35)
print('sample shape : ',samples.shape)
print('='*35)
print('='*35)
print('sample mean shape : ',sample_mean.shape)
print('='*35)
# Out:
# ===================================
# samples :  [[0.87168093 0.54439678 0.51754211 ... 0.99878594 0.83151169 0.46306393]
#  [0.985849   0.85749261 0.12758708 ... 0.61067747 0.88582065 0.81154918]
#  [0.84627707 0.43306912 0.50142673 ... 0.52905354 0.36951162 0.08273258]
#  ...
#  [0.98203641 0.78931131 0.73789076 ... 0.12894925 0.91845752 0.15279412]
#  [0.7740655  0.9897721  0.03113992 ... 0.84128369 0.7004357  0.99122077]
#  [0.38001657 0.21772466 0.0325235  ... 0.21715536 0.6993785  0.00198241]]
# ===================================
# sample shape :  (1000, 30)
# ===================================
# ===================================
# sample mean shape :  (1000,)
# ===================================

# %%
num_samples = 1000
saple_size = 50
# poisson distribution parameter
poisson_lambda = 5

# gamma distribution parameter
gamma_shape = 2
gamma_scale = 1

# Binomial distribution parameter
binomial_n = 10
binomial_p = 0.5

# Generate sample from Distributions
poisson_samples = np.random.poisson(lam=poisson_lambda, size=(num_samples,sample_size))
gamma_samples = np.random.gamma(shape=gamma_shape, scale=gamma_scale, size=(num_samples,sample_size))
binomial_samples = np.random.binomial(n=binomial_n, p=binomial_p, size=(num_samples,sample_size))

# Calculate the sample mean
poisson_mean = np.mean(poisson_samples,axis=1)
gamma_mean = np.mean(gamma_samples,axis=1)
binomial_mean = np.mean(binomial_samples,axis=1)

# Plot the Histogram of sample mean
figs, axs = plt.subplots(3,1,figsize=(7,15))

# Poisson Distrbution
axs[0].hist(poisson_mean,bins=30, density=True, edgecolor='black')
axs[0].set_title('Histogram of sample means (Poisson Distribution)')
axs[0].set_xlabel('Sample Mean')
axs[0].set_ylabel('Density')

# Gamma Distrbution
axs[1].hist(gamma_mean, bins=30, density=True, edgecolor='black')
axs[1].set_title('Histogram of sample means (Gamma Distribution)')
axs[1].set_xlabel('Sample Mean')
axs[1].set_ylabel('Density')

# Binomial Distrbution
axs[2].hist(binomial_mean,bins=30, density=True, edgecolor='black')
axs[2].set_title('Histogram of sample means (Binomial Distribution)')
axs[2].set_xlabel('Sample Mean')
axs[2].set_ylabel('Density')
plt.show()
